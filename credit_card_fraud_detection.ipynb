# %% [markdown]
# # 1. Problem Statement

# %% [markdown]
# *   Credit card fraud is a serious issue that can result in financial loses for individual and businesses.
# *   Machine can be used to detect fraudulent credit card transactions by analyzing large datasets and identifying patterns and anomalies.
# *   We use different neural networks that can accurately classify transactions either it is fraud(means 1) or genuine(means 0) and we also build a small neural network for this purpose.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 2. Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import seaborn as sns
from collections import Counter
np.random.seed(0)
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve, roc_auc_score, classification_report, accuracy_score, confusion_matrix 
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, f1_score, recall_score
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve, roc_auc_score, classification_report, accuracy_score, confusion_matrix 
from keras.models import Sequential
from keras.layers import Dense
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # 3. Data Processing

# %%
data = pd.read_csv('/content/drive/MyDrive/EE769_assignment2/A2_20d070053/creditcard.csv/creditcard.csv')

# %%
data.head(10)  #Showing first 10 different transctions and their results with features.
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
# 6  0.081213  0.464960  ... -0.167716 -0.270710 -0.154104 -0.780055  0.750137
# 7 -3.807864  0.615375  ...  1.943465 -1.015455  0.057504 -0.649709 -0.415267
# 8  0.851084 -0.392048  ... -0.073425 -0.268092 -0.204233  1.011592  0.373205
# 9  0.069539 -0.736727  ... -0.246914 -0.633753 -0.120794 -0.385050 -0.069733
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
# 5  0.105915  0.253844  0.081080    3.67      0
# 6 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.051634 -1.206921 -1.085339   40.80      0
# 8 -0.384157  0.011747  0.142404   93.20      0
# 9  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
data.describe()  # Describing Mean,Min,Max,Bount,std,and some other properties of Features.
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
data.isnull().sum()  # Calculating no, of Null values per feature.
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data.Class.value_counts()   #Showing no. of genuine and fraud transctions.
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# # Histogram for Feature Time

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(12,4))

ax1.hist(data["Time"][data["Class"] == 1], bins = 50)
ax1.set_title('Fraudulent')

ax2.hist(data["Time"][data["Class"] == 0], bins = 50)
ax2.set_title('Genuine')

plt.xlabel('Seconds after transaction number zero')
plt.ylabel('Number of Transactions')
plt.show()

# %% [markdown]
# The transactions occur in a cyclic way. But the time feature does not provide any useful information as the time when the first transaction was initiated is not given. Thus, we will drop this feature.

# %% [markdown]
# **3.1 Scale the Amount variable**

# %%
#Variance
data.var()
# Out:
# Time      2.255124e+09
# V1        3.836489e+00
# V2        2.726820e+00
# V3        2.299029e+00
# V4        2.004684e+00
# V5        1.905081e+00
# V6        1.774946e+00
# V7        1.530401e+00
# V8        1.426479e+00
# V9        1.206992e+00
# V10       1.185594e+00
# V11       1.041855e+00
# V12       9.984034e-01
# V13       9.905708e-01
# V14       9.189055e-01
# V15       8.378034e-01
# V16       7.678191e-01
# V17       7.213734e-01
# V18       7.025394e-01
# V19       6.626619e-01
# V20       5.943254e-01
# V21       5.395255e-01
# V22       5.266428e-01
# V23       3.899507e-01
# V24       3.668084e-01
# V25       2.717308e-01
# V26       2.325429e-01
# V27       1.629192e-01
# V28       1.089550e-01
# Amount    6.256007e+04
# Class     1.724507e-03
# dtype: float64

# %% [markdown]
# Amount needs to be scaled. As if a feature has a variance orders of magnitude larger than the rest of the features, then it might dominate and , make the estimator unable to learn from other features as expected

# %%
scaling_model = StandardScaler()
data['Normalized_Amount'] = scaling_model.fit_transform(data['Amount'].values.reshape(-1, 1))
data = data.drop(['Amount'],axis=1)

# %% [markdown]
# **3.2 Split data into training set and test set**

# %%
X = data.drop(['Class','Time'], axis = 1)
y = data['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %% [markdown]
# **3.3 Convert data**

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %% [markdown]
# # Different Models Building and Training

# %% [markdown]
# Before we build the model, we use standard scaler function to scale the values into a common range.

# %% [markdown]
# *   **Logistic Regression**
# https://machinelearningknowledge.ai/python-sklearn-logistic-regression-tutorial-with-example/#:~:text=For%20performing%20logistic%20regression%20in%20Python%2C%20we%20have,will%20use%20credit%20card%20data%20to%20predict%20fraud.

# %%
scaler = StandardScaler()
lr = LogisticRegression(class_weight={0:1, 1:10}) #Passing defalut parameters
model1 = Pipeline([('standardize',scaler),('log_reg',lr)])

# %%
history_model1 = model1.fit(X_train,y_train)
history_model1
# Out:
# Pipeline(steps=[('standardize', StandardScaler()),
#                 ('log_reg', LogisticRegression(class_weight={0: 1, 1: 10}))])

# %% [markdown]
# **Traininy Accuracy**

# %%
y_train_model1 = history_model1.predict(X_train)

train_accuracy1 = accuracy_score(y_train, y_train_model1)*100
train_auc_roc11 = roc_auc_score(y_train, y_train_model1.round())*100

print('Confusion matrix:\n', confusion_matrix(y_train, y_train_model1))

print('Training AUC: %.4f %%' % train_auc_roc11)

print('Training accuracy: %.4f %%' % train_accuracy1)
# Out:
# Confusion matrix:
#  [[198934     85]
#  [    58    287]]
# Training AUC: 91.5728 %
# Training accuracy: 99.9283 %

# %% [markdown]
# **Tessting Score**

# %%
def plot_confusion_matrix(cm):
    class_feat=data['Class'].copy()
    class_feat= class_feat.unique()
    fig, ax = plt.subplots(figsize=(5,5))
    sn.heatmap(cm, annot=True, fmt='d', xticklabels=class_feat, yticklabels=class_feat)
    plt.ylabel('Actual Class')
    plt.xlabel('Predicted Class')
    plt.show()

# %%
y_test_model1 = history_model1.predict(X_test)
cm1 = confusion_matrix(y_test,y_test_model1.round())
plot_confusion_matrix(cm1)
print(cm1)
# Out:
# [[85269    27]
#  [   28   119]]

# %%
def print_scores(org,pred):
    accuracy = accuracy_score(org,pred)
    precision = precision_score(org,pred)
    recall = recall_score(org,pred)
    f1 = f1_score(org,pred)
    print("Accuracy : ",accuracy)
    print("Precision : ",precision)
    print("Recall : ",recall)
    print("F1 Score : ",f1)

# %%
print_scores(y_test,y_test_model1.round())
a1 = accuracy_score(y_test,y_test_model1.round())
f1 = f1_score(y_test,y_test_model1.round())
r1 = recall_score(y_test,y_test_model1.round())
p1 = precision_score(y_test,y_test_model1.round())
# Out:
# Accuracy :  0.9993562960102056
# Precision :  0.815068493150685
# Recall :  0.8095238095238095
# F1 Score :  0.8122866894197952

# %% [markdown]
# *   **SVC**
# *   https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.**html**

# %%
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
model2 =  make_pipeline(scaler, SVC(gamma='auto'))

# %%
history_model2 = model2.fit(X_train,y_train)
history_model2
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('svc', SVC(gamma='auto'))])

# %% [markdown]
# **Training Accyracy**

# %%
y_train_model2 = history_model2.predict(X_train)

train_accuracy2 = accuracy_score(y_train, y_train_model2)*100
train_auc_roc2 = roc_auc_score(y_train, y_train_model2.round())*100

print('Confusion matrix:\n', confusion_matrix(y_train, y_train_model2))

print('Training AUC: %.4f %%' % train_auc_roc2)

print('Training accuracy: %.4f %%' % train_accuracy2)
# Out:
# Confusion matrix:
#  [[199013      6]
#  [    61    284]]
# Training AUC: 91.1579 %
# Training accuracy: 99.9664 %

# %% [markdown]
# **Testing Accuracy**

# %%
y_test_model2 = history_model2.predict(X_test)
cm2 = confusion_matrix(y_test,y_test_model2.round())
plot_confusion_matrix(cm2)
print(cm2)
# Out:
# [[85290     6]
#  [   57    90]]

# %%
# Test scores
print_scores(y_test,y_test_model2.round())
a2 = accuracy_score(y_test,y_test_model2.round())
f2 = f1_score(y_test,y_test_model2.round())
r2 = recall_score(y_test,y_test_model2.round())
p2 = precision_score(y_test,y_test_model2.round())
# Out:
# Accuracy :  0.9992626663389628
# Precision :  0.9375
# Recall :  0.6122448979591837
# F1 Score :  0.7407407407407408

# %% [markdown]
# * **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
# Creating the classifier object
model3 = DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=3, min_samples_leaf=5)

# %%
history_model3 = model3.fit(X_train,y_train)
history_model3
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=100)

# %% [markdown]
# **Training Accuracy**

# %%
y_train_model3 = history_model3.predict(X_train)

train_accuracy3 = accuracy_score(y_train, y_train_model3)*100
train_auc_roc3 = roc_auc_score(y_train, y_train_model3.round())*100

print('Confusion matrix:\n', confusion_matrix(y_train, y_train_model3))

print('Training AUC: %.4f %%' % train_auc_roc3)

print('Training accuracy: %.4f %%' % train_accuracy3)
# Out:
# Confusion matrix:
#  [[198968     51]
#  [    84    261]]
# Training AUC: 87.8133 %
# Training accuracy: 99.9323 %

# %% [markdown]
# **Testing Score**

# %%
y_test_model3 = history_model3.predict(X_test)
cm3 = confusion_matrix(y_test,y_test_model3.round())
plot_confusion_matrix(cm3)
print(cm3)
# Out:
# [[85273    23]
#  [   39   108]]

# %%
print_scores(y_test,y_test_model3.round())
a3 = accuracy_score(y_test,y_test_model3.round())
f3 = f1_score(y_test,y_test_model3.round())
r3 = recall_score(y_test,y_test_model3.round())
p3 = precision_score(y_test,y_test_model3.round())
# Out:
# Accuracy :  0.9992743700478681
# Precision :  0.8244274809160306
# Recall :  0.7346938775510204
# F1 Score :  0.7769784172661872

# %% [markdown]
# * **Neural Networks**
# https://realpython.com/python-ai-neural-network/*italicized text*

# %%
from sklearn.neural_network import MLPClassifier
model4 = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(5, 2), random_state=1)
history_model4 = model4.fit(X_train,y_train)

# %%
history_model4 = model4.fit(X_train,y_train)

# %% [markdown]
# **Traininy Accuracy**

# %%
y_train_model4 = history_model4.predict(X_train)

train_accuracy4 = accuracy_score(y_train, y_train_model4)*100
train_auc_roc4 = roc_auc_score(y_train, y_train_model4.round())*100

print('Confusion matrix:\n', confusion_matrix(y_train, y_train_model4))

print('Training AUC: %.4f %%' % train_auc_roc4)

print('Training accuracy: %.4f %%' % train_accuracy4)
# Out:
# Confusion matrix:
#  [[199001     18]
#  [    76    269]]
# Training AUC: 88.9810 %
# Training accuracy: 99.9529 %

# %% [markdown]
# **Testing Accuracy**

# %%
y_test_model4 = history_model4.predict(X_test)
cm4 = confusion_matrix(y_test,y_test_model4.round())
plot_confusion_matrix(cm4)
print(cm4)
# Out:
# [[85288     8]
#  [   43   104]]

# %%
print_scores(y_test,y_test_model4.round())
a4 = accuracy_score(y_test,y_test_model4.round())
f4 = f1_score(y_test,y_test_model4.round())
r4 = recall_score(y_test,y_test_model4.round())
p4 = precision_score(y_test,y_test_model4.round())
# Out:
# Accuracy :  0.999403110845827
# Precision :  0.9285714285714286
# Recall :  0.7074829931972789
# F1 Score :  0.8030888030888031

# %% [markdown]
# * KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier(n_neighbors=7)
model_knn = model_knn.fit(X_train,y_train)
model_knn
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
model_knn = model_knn.fit(X_train,y_train)
model_knn
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %% [markdown]
# * Training Accuracy

# %%
y_train_model_knn = model_knn.predict(X_train)

train_accuracy_knn = accuracy_score(y_train, y_train_model_knn)*100
train_auc_roc3 = roc_auc_score(y_train, y_train_model3.round())*100

print('Confusion matrix:\n', confusion_matrix(y_train, y_train_model3))

print('Training AUC: %.4f %%' % train_auc_roc3)

print('Training accuracy: %.4f %%' % train_accuracy3)
# Out:
# Confusion matrix:
#  [[198968     51]
#  [    84    261]]
# Training AUC: 87.8133 %
# Training accuracy: 99.9323 %

# %% [markdown]
# * Testing Accuracy

# %%
y_test_model_knn = model_knn.predict(X_test)
cm4 = confusion_matrix(y_test,y_test_model_knn.round())
plot_confusion_matrix(cm4)
print(cm4)
# Out:
# [[85289     7]
#  [   40   107]]

# %%
print_scores(y_test,y_test_model_knn.round())
a5 = accuracy_score(y_test,y_test_model_knn.round())
f5 = f1_score(y_test,y_test_model_knn.round())
r5 = recall_score(y_test,y_test_model_knn.round())
p5 = precision_score(y_test,y_test_model_knn.round())
# Out:
# Accuracy :  0.9994499256814484
# Precision :  0.9385964912280702
# Recall :  0.7278911564625851
# F1 Score :  0.8199233716475096

# %% [markdown]
# # 4. Deep neural network

# %% [markdown]
# 4.1 create Model

# %%
model = Sequential()
model.add(Dense(input_dim = 29, units = 24, activation = 'relu'))
model.add(Dense(units = 16, activation = 'relu'))
model.add(Dense(units = 8, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 24)                720
#
#  dense_5 (Dense)             (None, 16)                400
#
#  dense_6 (Dense)             (None, 8)                 136
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,265
# Trainable params: 1,265
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 4.2 Fit Model

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
history = model.fit(X_train, y_train, batch_size = 16, epochs = 10)
# Out:
# Epoch 1/10
# 12461/12461 [==============================] - 28s 2ms/step - loss: 0.0106 - accuracy: 0.9970
# Epoch 2/10
# 12461/12461 [==============================] - 26s 2ms/step - loss: 0.0032 - accuracy: 0.9993
# Epoch 3/10
# 12461/12461 [==============================] - 23s 2ms/step - loss: 0.0030 - accuracy: 0.9994
# Epoch 4/10
# 12461/12461 [==============================] - 25s 2ms/step - loss: 0.0028 - accuracy: 0.9994
# Epoch 5/10
# 12461/12461 [==============================] - 24s 2ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 6/10
# 12461/12461 [==============================] - 24s 2ms/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 7/10
# 12461/12461 [==============================] - 23s 2ms/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 8/10
# 12461/12461 [==============================] - 24s 2ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 9/10
# 12461/12461 [==============================] - 24s 2ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 10/10
# 12461/12461 [==============================] - 25s 2ms/step - loss: 0.0023 - accuracy: 0.9995

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %% [markdown]
# 4.3 Evaluate model

# %%
score = model.evaluate(X_test, y_test)
print(score)
# Out:
# 2671/2671 [==============================] - 6s 2ms/step - loss: 0.0033 - accuracy: 0.9994
# [0.003250452224165201, 0.9994031190872192]

# %%
y_pred = model.predict(X_test)
# Out:
# 2671/2671 [==============================] - 4s 2ms/step

# %%
cm = confusion_matrix(y_test, y_pred.round())
print(cm)
plot_confusion_matrix(cm)
# Out:
# [[85278    18]
#  [   33   114]]

# %%
print_scores(y_test,y_pred.round())
a6 = accuracy_score(y_test,y_pred.round())
f6 = f1_score(y_test,y_pred.round())
r6 = recall_score(y_test,y_pred.round())
p6 = precision_score(y_test,y_pred.round())
# Out:
# Accuracy :  0.999403110845827
# Precision :  0.8636363636363636
# Recall :  0.7755102040816326
# F1 Score :  0.8172043010752688

# %% [markdown]
# * Accuracy plot of different models used

# %%
f_score = [f1,f2,f3,f4,f5,f6]
print(f_score)
models = ['Logistic Regration','SVC','DecisionTree','NN','KNN','Custom NN']
fig = plt.figure()
plt.xlabel('Models')
plt.ylabel("F1-Score")
plt.plot(models,f_score)
# Out:
# [0.8122866894197952, 0.7407407407407408, 0.7769784172661872, 0.8030888030888031, 0.8199233716475096, 0.8172043010752688]

# %%
p_score = [p1,p2,p3,p4,p5,p6]
print(p_score)
models = ['Logistic Regration','SVC','DecisionTree','NN','KNN','Custom NN']
fig = plt.figure()
plt.xlabel('Models')
plt.ylabel("precision value")
plt.plot(models,p_score)
# Out:
# [0.815068493150685, 0.9375, 0.8244274809160306, 0.9285714285714286, 0.9385964912280702, 0.8636363636363636]

# %%
r_score = [r1,r2,r3,r4,r5,r6]
print(r_score)
models = ['Logistic Regration','SVC','DecisionTree','NN','KNN','Custom NN']
fig = plt.figure()
plt.xlabel('Models')
plt.ylabel("Recall value")
plt.plot(models,r_score)
# Out:
# [0.8095238095238095, 0.6122448979591837, 0.7346938775510204, 0.7074829931972789, 0.7278911564625851, 0.7755102040816326]

# %% [markdown]
# * Undersampling & model test
#
# Sampling is performed before data spliting which should be the case if future data is unbalanced, otherwise, sampling needs to be performed only on train set

# %%
class1_indexes = np.array(data[data.Class == 1].index)
class0_indexes = np.array(data[data.Class == 0].index)
print(len(class0_indexes))
print(len(class1_indexes))
# Out:
# 284315
# 492

# %%
class0_indexes = data[data.Class == 0].index
final_class0_indexes = np.random.choice(class0_indexes, len(class1_indexes), replace = False)
final_class0_indexes = np.array(final_class0_indexes)

# %%
under_sample_ind = np.concatenate([class1_indexes, final_class0_indexes])

# %%
print(len(under_sample_ind))
# Out:
# 984

# %%
under_sample_data = data.iloc[under_sample_ind, :]

# %%
X_undersample = under_sample_data.iloc[:, :]
y_undersample = under_sample_data.iloc[:, under_sample_data.columns == 'Class']
X_undersample = X_undersample.drop(['Class','Time'], axis = 1)

X_train, X_test, y_train, y_test = train_test_split(X_undersample, y_undersample, test_size = 0.3, random_state=0)

# %%
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
history_model4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 24)                720
#
#  dense_5 (Dense)             (None, 16)                400
#
#  dense_6 (Dense)             (None, 8)                 136
#
#  dense_7 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 1,265
# Trainable params: 1,265
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_model4.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
history2 = history_model4.fit(X_train, y_train, batch_size = 16, epochs = 10)
# Out:
# Epoch 1/10
# 43/43 [==============================] - 1s 3ms/step - loss: 0.2661 - accuracy: 0.9259
# Epoch 2/10
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1489 - accuracy: 0.9375
# Epoch 3/10
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1194 - accuracy: 0.9448
# Epoch 4/10
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1129 - accuracy: 0.9462
# Epoch 5/10
# 43/43 [==============================] - 0s 2ms/step - loss: 0.1070 - accuracy: 0.9520
# Epoch 6/10
# 43/43 [==============================] - 0s 3ms/step - loss: 0.1028 - accuracy: 0.9520
# Epoch 7/10
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0985 - accuracy: 0.9535
# Epoch 8/10
# 43/43 [==============================] - 0s 3ms/step - loss: 0.0945 - accuracy: 0.9564
# Epoch 9/10
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0917 - accuracy: 0.9564
# Epoch 10/10
# 43/43 [==============================] - 0s 2ms/step - loss: 0.0873 - accuracy: 0.9637

# %%
# summarize history for accuracy
plt.plot(history2.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history2.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
y_pred = history_model4.predict(X_test)

cm = confusion_matrix(y_test, y_pred.round())
plot_confusion_matrix(cm)
plt.show()
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
print_scores(y_test,y_pred.round())
# Out:
# Accuracy :  0.9527027027027027
# Precision :  0.9925925925925926
# Recall :  0.9115646258503401
# F1 Score :  0.9503546099290779

# %% [markdown]
# * SMOTE & Model test
#
# sampling is performed before data spliting which should be the case if future data is unbalanced

# %%
X_created, y_created = SMOTE().fit_resample(X, y)

# %%
counter = Counter(y_created)
print(counter)
# Out:
# Counter({0: 284315, 1: 284315})

# %%
X_train, X_test, y_train, y_test = train_test_split(X_created, y_created, test_size = 0.3,random_state=0)

X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
history3 = history_model4.fit(X_train, y_train, batch_size = 16, epochs = 10)
# Out:
# Epoch 1/10
# 24878/24878 [==============================] - 48s 2ms/step - loss: 0.0187 - accuracy: 0.9940
# Epoch 2/10
# 24878/24878 [==============================] - 62s 2ms/step - loss: 0.0072 - accuracy: 0.9982
# Epoch 3/10
# 24878/24878 [==============================] - 53s 2ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 4/10
# 24878/24878 [==============================] - 48s 2ms/step - loss: 0.0049 - accuracy: 0.9988
# Epoch 5/10
# 24878/24878 [==============================] - 48s 2ms/step - loss: 0.0044 - accuracy: 0.9990
# Epoch 6/10
# 24878/24878 [==============================] - 50s 2ms/step - loss: 0.0040 - accuracy: 0.9991
# Epoch 7/10
# 24878/24878 [==============================] - 47s 2ms/step - loss: 0.0036 - accuracy: 0.9992
# Epoch 8/10
# 24878/24878 [==============================] - 47s 2ms/step - loss: 0.0039 - accuracy: 0.9992
# Epoch 9/10
# 24878/24878 [==============================] - 48s 2ms/step - loss: 0.0033 - accuracy: 0.9992
# Epoch 10/10
# 24878/24878 [==============================] - 47s 2ms/step - loss: 0.0032 - accuracy: 0.9993

# %%
# summarize history for accuracy
plt.plot(history3.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history3.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train'], loc='upper left')
plt.show()

# %%
y_pred = history_model4.predict(X_test)
# Out:
# 5331/5331 [==============================] - 6s 1ms/step

# %%
cm = confusion_matrix(y_test, y_pred.round())
plot_confusion_matrix(cm)
plt.show()

# %%
print_scores(y_test,y_pred.round())
# Out:
# Accuracy :  0.9988217294198336
# Precision :  0.9988059002575509
# Recall :  0.9988409801327605
# F1 Score :  0.998823439887144
